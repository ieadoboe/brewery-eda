# %% [markdown]
# # Data Preprocess

# %%
import pandas as pd
import numpy as np

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("abcbbong/brewery-csv")

print("Path to dataset files:", path)
# Out:
# ...
# Path to dataset files: /Users/isaacadoboe/.cache/kagglehub/datasets/abcbbong/brewery-csv/versions/1

# %%
df = pd.read_csv("/Users/isaacadoboe/.cache/kagglehub/datasets/abcbbong/brewery-csv/versions/1/brewery_data_complete_extended.csv")
df.tail()
# Out:
#          Batch_ID            Brew_Date  Beer_Style      SKU         Location  \
# 9999995   4575645  2023-12-31 23:58:59       Stout  Bottles        Yelahanka
# 9999996   2074362  2023-12-31 23:59:18  Wheat Beer  Bottles  Electronic City
# 9999997    177617  2023-12-31 23:59:41         IPA  Bottles      Malleswaram
# 9999998   7306891  2023-12-31 23:59:45         Ale     Kegs  Electronic City
# 9999999   5072143  2023-12-31 23:59:54  Wheat Beer    Pints  Electronic City
#
#          Fermentation_Time  Temperature  pH_Level   Gravity  Alcohol_Content  \
# 9999995                 12    20.719151  4.944343  1.049876         5.437139
# 9999996                 19    16.970908  5.121963  1.037019         5.102428
# 9999997                 10    24.386184  4.747588  1.047490         5.025251
# 9999998                 18    18.056172  5.007909  1.046138         5.843181
# 9999999                 11    22.195310  4.883125  1.074231         5.307453
#
# ...

# %%
df.Batch_ID.nunique()
# Out:
# 10000000

# %%
df.shape
# Out:
# (10000000, 20)

# %%
filtered_df = df[df.SKU == "Bottles"]
filtered_df.tail()
# Out:
#          Batch_ID            Brew_Date  Beer_Style      SKU         Location  \
# 9999990   4874627  2023-12-31 23:57:56  Wheat Beer  Bottles      Rajajinagar
# 9999991   4797863  2023-12-31 23:58:02        Sour  Bottles      Malleswaram
# 9999995   4575645  2023-12-31 23:58:59       Stout  Bottles        Yelahanka
# 9999996   2074362  2023-12-31 23:59:18  Wheat Beer  Bottles  Electronic City
# 9999997    177617  2023-12-31 23:59:41         IPA  Bottles      Malleswaram
#
#          Fermentation_Time  Temperature  pH_Level   Gravity  Alcohol_Content  \
# 9999990                 17    21.292334  4.592902  1.073923         5.455494
# 9999991                 17    19.852307  5.486420  1.073821         5.771123
# 9999995                 12    20.719151  4.944343  1.049876         5.437139
# 9999996                 19    16.970908  5.121963  1.037019         5.102428
# 9999997                 10    24.386184  4.747588  1.047490         5.025251
#
# ...

# %%
dataset = filtered_df.sample(1000, replace=False)

# %%
dataset.shape
# Out:
# (1000, 20)

# %%
dataset.columns
# Out:
# Index(['Batch_ID', 'Brew_Date', 'Beer_Style', 'SKU', 'Location',
#        'Fermentation_Time', 'Temperature', 'pH_Level', 'Gravity',
#        'Alcohol_Content', 'Bitterness', 'Color', 'Ingredient_Ratio',
#        'Volume_Produced', 'Total_Sales', 'Quality_Score',
#        'Brewhouse_Efficiency', 'Loss_During_Brewing',
#        'Loss_During_Fermentation', 'Loss_During_Bottling_Kegging'],
#       dtype='object')

# %%
dataset = dataset.drop(columns=['Batch_ID', 'Brew_Date', 'SKU', 'Color', 'Ingredient_Ratio'])

# %%
dataset.tail()
# Out:
#          Beer_Style         Location  Fermentation_Time  Temperature  \
# 6464281       Stout      Malleswaram                 15    22.171126
# 4633539     Pilsner        Yelahanka                 15    21.286921
# 5899713  Wheat Beer  Electronic City                 10    23.169087
# 8708999  Wheat Beer       HSR Layout                 15    18.361260
# 1510785        Sour      Malleswaram                 12    23.563918
#
#          pH_Level   Gravity  Alcohol_Content  Bitterness  Volume_Produced  \
# 6464281  4.935160  1.055155         5.555964          22             3060
# 4633539  5.378679  1.076624         5.080106          57             4347
# 5899713  5.149985  1.062829         4.518311          54             3456
# 8708999  5.308781  1.032336         5.374664          25              832
# 1510785  5.091756  1.054020         4.840496          34             4008
#
#           Total_Sales  Quality_Score  Brewhouse_Efficiency  \
# ...

# %%
dataset = dataset[:100]

# %%
dataset.to_csv("bottle_dataset.csv")
